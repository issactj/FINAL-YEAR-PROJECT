# %%
"""
    Import all the important required Deep Learning Libraries to train the gestures model.
    
    Keras is an Application Programming Interface (API) which can run on top of tensorflow.
    
    tensorflow will be the main deep learning module we will use to build our deep learning model.
    
    from tensorflow we will be referring to a pre-trained model called VGG-16. We will be 
    using VGG-16 with custom convolutional neural networks (CNN's) i.e. We will be using 
    our transfer learning model VGG-16 alongside our own custom model to train an overall 
    accurate model. The VGG-16 model in keras is pretrained with the imagenet weights.
    
    The ImageDataGenerator is used for Data augmentation where the model can see more copies of 
        the model. Data Augmentation is used for creating replications of the original images 
        and using those transformations in each epoch.
        
    The layers for training which will be used are as follows:
    1. Input = The input layer which we pass the input shape.
    2. Conv2D = The Convoluional layer combined with Input to provide a output of tensors
    3. Maxpool2D = Downsampling the Data from the convolutional layer.
    4. Batch normalization = It is a technique for training very deep neural networks that standardizes 
       the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning 
       process and dramatically reducing the number of training epochs required to train deep networks.
    5. Dropout = Dropout is a technique where randomly selected neurons are ignored during training. 
                 They are “dropped-out” randomly and this prevents over-fitting.
    6. Dense = Fully Connected layers.
    7. Flatten = Flatten the entire structure to a 1-D array.
    
    The Models can be built in a model like structure as shown in this particular model or can be built 
        in a sequential manner.
        
    Use of l2 regularization for fine tuning.
    
    The optimizer used will be Adam as it is performs better than the other optimizers on this model.
    
    We are also importing the os module to make it compatible with the windows environment. 

"""

import keras
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Dropout, BatchNormalization, Dense, Flatten
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import os

# %%
"""
    Specify the train and the validation directory for the stored images.
    train_dir is the directory which will contain the set of images for training.
    validation_dir is the directory will contain the set of validation images.

"""

train_dir = "C:/Users/dell/Desktop/PROJECT DATA/asl_alphabet_train/asl_alphabet_train/train1/"
validation_dir = "C:/Users/dell/Desktop/PROJECT DATA/asl_alphabet_train/asl_alphabet_train/validation1/"

# %%
"""
    We have 4 classes of gestures which is namely punch, Victory, Super 
    and Loser.
    
    Each of the images have a height and width of 200 as well as it is a 
    RGB image i.e. a 3-Dimensional image.
    
    We will be using a batch_size of 128 for the image Data Augmentation.

"""

num_classes = 4

Img_Height = 200
Img_width = 200

batch_size = 128

# %%
"""
    Reference: https://keras.io/api/preprocessing/image/
    
    The ImageDataGenerator is used here to make copies of the image. 
    This modification will be applied to each epoch as well .

    
    train_datagen.flow_from_directory Takes the path to a directory & generates batches of 
    augmented data.

"""

train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   width_shift_range=0.4,
                                   height_shift_range=0.4,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(Img_Height, Img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                             target_size=(Img_Height, Img_width),
                                                             batch_size=batch_size,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 9600 images belonging to 4 classes.
# Found 2400 images belonging to 4 classes.

# %%
""" 
    We will be importing VGG-16 model and the VGG-16 has no top layer,
    we are going to add custom layers into the VGG16. 
    To Avoid training VGG16 Layers we give the command below:
    layers.trainable = False


"""

VGG16_MODEL = VGG16(input_shape=(Img_width, Img_Height, 3), include_top=False, weights='imagenet')

for layers in VGG16_MODEL.layers: 
    layers.trainable=False

for layers in VGG16_MODEL.layers:
    print(layers.trainable)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
"""
    The Finger Gesture Model we are building will be trained by using 
    transfer learning. We will be using VGG-16 model with no top layer.
    We will be adding custom layers to the top layer of the VGG-16 model 
    and then we will use this transfer learning model for prediction of
    the finger gestures.
    
    The Custom layer consists of the input layer which is basically the 
    output of the VGG-16 Model. We add a convolutional layer with 32 filters,
    kernel_size of (3,3) and default strides of (1,1) and we use activation
    as relu with he_normal as initializer.
    
    We will be using the pooling layer to downsampled the layers from the
    convolutional layer.
    
    The 2 fully connected layers are used with activation as relu i.e. a 
    Dense architecture after the sample being passed through a flatten
    layer.
    
    The output layer has a softmax activation with num_classes is 4 that
    predicts the probabilies for the num_classes namely Punch, Super, 
    Victoy and Loser.
    
    The final Model takes the input as the start of the VGG-16 model
    and outputs as the final output layer.

"""

# Input layer
input_layer = VGG16_MODEL.output

# Convolutional Layer
Conv1 = Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='valid',
               data_format='channels_last', activation='relu', 
               kernel_initializer=keras.initializers.he_normal(seed=0), 
               name='Conv1')(input_layer)

# MaxPool Layer
Pool1 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid', 
                  data_format='channels_last',name='Pool1')(Conv1)

# Flatten
flatten = Flatten(data_format='channels_last',name='Flatten')(Pool1)

# Fully Connected layer-1
FC1 = Dense(units=30, activation='relu', 
            kernel_initializer=keras.initializers.glorot_normal(seed=32), 
            name='FC1')(flatten)

# Fully Connected layer-2
FC2 = Dense(units=30, activation='relu', 
            kernel_initializer=keras.initializers.glorot_normal(seed=33),
            name='FC2')(FC1)

# Output layer
Out = Dense(units=num_classes, activation='softmax', 
            kernel_initializer=keras.initializers.glorot_normal(seed=3), 
            name='Output')(FC2)

model1 = Model(inputs=VGG16_MODEL.input,outputs=Out)

# %%
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 4, 4, 32)          147488
# _________________________________________________________________
# Pool1 (MaxPooling2D)         (None, 2, 2, 32)          0
# _________________________________________________________________
# Flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# FC1 (Dense)                  (None, 30)                3870
# _________________________________________________________________
# FC2 (Dense)                  (None, 30)                930
# _________________________________________________________________
# Output (Dense)               (None, 4)                 124
# =================================================================
# Total params: 14,867,100
# Trainable params: 152,412
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from tensorflow import keras
from keras.utils.vis_utils import plot_model
from keras.utils import np_utils

keras.utils.plot_model(model1, to_file='model1.png', show_layer_names=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard

checkpoint = ModelCheckpoint("gesturefinal.h5", monitor='accuracy', verbose=1,
    save_best_only=True, mode='auto', save_freq=1)

reduce = ReduceLROnPlateau(monitor='accuracy', factor=0.2, patience=5, min_lr=0.00001, verbose = 1)

logdir='logsgesture'
tensorboard_Visualization = TensorBoard(log_dir=logdir, histogram_freq=True)

# %%
model1.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy']
              )
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
train_samples = 9600
validation_samples = 2400

epochs = 50

batch_size = 128

model1.fit(train_generator,
           steps_per_epoch = train_samples//batch_size,
           epochs = epochs,
           callbacks = [checkpoint, reduce, tensorboard_Visualization],
           validation_data = validation_generator,
           validation_steps = validation_samples//batch_size)
# Out:
# Epoch 1/50
#  1/75 [..............................] - ETA: 24:13 - loss: 1.8412 - accuracy: 0.1953
# Epoch 00001: accuracy improved from -inf to 0.19531, saving model to gesturefinal.h5
#  2/75 [..............................] - ETA: 17:30 - loss: 1.6408 - accuracy: 0.2070
# Epoch 00001: accuracy improved from 0.19531 to 0.20703, saving model to gesturefinal.h5
#  3/75 [>.............................] - ETA: 19:22 - loss: 1.5599 - accuracy: 0.2266
# Epoch 00001: accuracy improved from 0.20703 to 0.22656, saving model to gesturefinal.h5
#  4/75 [>.............................] - ETA: 18:29 - loss: 1.5178 - accuracy: 0.2305
# Epoch 00001: accuracy improved from 0.22656 to 0.23047, saving model to gesturefinal.h5
#  5/75 [=>............................] - ETA: 18:18 - loss: 1.4981 - accuracy: 0.2359
# Epoch 00001: accuracy improved from 0.23047 to 0.23594, saving model to gesturefinal.h5
#  6/75 [=>............................] - ETA: 18:04 - loss: 1.4794 - accuracy: 0.2383
# Epoch 00001: accuracy improved from 0.23594 to 0.23828, saving model to gesturefinal.h5
#  7/75 [=>............................] - ETA: 17:56 - loss: 1.4635 - accuracy: 0.2489
# Epoch 00001: accuracy improved from 0.23828 to 0.24888, saving model to gesturefinal.h5
#  8/75 [==>...........................] - ETA: 17:50 - loss: 1.4499 - accuracy: 0.2588
# Epoch 00001: accuracy improved from 0.24888 to 0.25879, saving model to gesturefinal.h5
#  9/75 [==>...........................] - ETA: 17:39 - loss: 1.4413 - accuracy: 0.2630
# Epoch 00001: accuracy improved from 0.25879 to 0.26302, saving model to gesturefinal.h5
# 10/75 [===>..........................] - ETA: 17:27 - loss: 1.4341 - accuracy: 0.2664
# Epoch 00001: accuracy improved from 0.26302 to 0.26641, saving model to gesturefinal.h5
# 11/75 [===>..........................] - ETA: 17:15 - loss: 1.4252 - accuracy: 0.2763
# Epoch 00001: accuracy improved from 0.26641 to 0.27628, saving model to gesturefinal.h5
# 12/75 [===>..........................] - ETA: 17:02 - loss: 1.4188 - accuracy: 0.2839
# Epoch 00001: accuracy improved from 0.27628 to 0.28385, saving model to gesturefinal.h5
# 13/75 [====>.........................] - ETA: 16:52 - loss: 1.4111 - accuracy: 0.2927
# Epoch 00001: accuracy improved from 0.28385 to 0.29267, saving model to gesturefinal.h5
# 14/75 [====>.........................] - ETA: 16:40 - loss: 1.4059 - accuracy: 0.2946
# Epoch 00001: accuracy improved from 0.29267 to 0.29464, saving model to gesturefinal.h5
# 15/75 [=====>........................] - ETA: 16:29 - loss: 1.3993 - accuracy: 0.3026
# Epoch 00001: accuracy improved from 0.29464 to 0.30260, saving model to gesturefinal.h5
# 16/75 [=====>........................] - ETA: 16:16 - loss: 1.3938 - accuracy: 0.3105
# Epoch 00001: accuracy improved from 0.30260 to 0.31055, saving model to gesturefinal.h5
# 17/75 [=====>........................] - ETA: 16:03 - loss: 1.3873 - accuracy: 0.3171
# Epoch 00001: accuracy improved from 0.31055 to 0.31710, saving model to gesturefinal.h5
# 18/75 [======>.......................] - ETA: 15:49 - loss: 1.3798 - accuracy: 0.3307
# Epoch 00001: accuracy improved from 0.31710 to 0.33073, saving model to gesturefinal.h5
# 19/75 [======>.......................] - ETA: 15:35 - loss: 1.3755 - accuracy: 0.3343
# Epoch 00001: accuracy improved from 0.33073 to 0.33429, saving model to gesturefinal.h5
# 20/75 [=======>......................] - ETA: 15:21 - loss: 1.3705 - accuracy: 0.3383
# Epoch 00001: accuracy improved from 0.33429 to 0.33828, saving model to gesturefinal.h5
# 21/75 [=======>......................] - ETA: 15:06 - loss: 1.3640 - accuracy: 0.3430
# Epoch 00001: accuracy improved from 0.33828 to 0.34301, saving model to gesturefinal.h5
# 22/75 [=======>......................] - ETA: 14:50 - loss: 1.3571 - accuracy: 0.3498
# Epoch 00001: accuracy improved from 0.34301 to 0.34979, saving model to gesturefinal.h5
# 23/75 [========>.....................] - ETA: 14:35 - loss: 1.3505 - accuracy: 0.3526
# Epoch 00001: accuracy improved from 0.34979 to 0.35258, saving model to gesturefinal.h5
# 24/75 [========>.....................] - ETA: 14:19 - loss: 1.3435 - accuracy: 0.3630
# Epoch 00001: accuracy improved from 0.35258 to 0.36296, saving model to gesturefinal.h5
# 25/75 [=========>....................] - ETA: 14:03 - loss: 1.3367 - accuracy: 0.3691
# Epoch 00001: accuracy improved from 0.36296 to 0.36906, saving model to gesturefinal.h5
# 26/75 [=========>....................] - ETA: 13:50 - loss: 1.3303 - accuracy: 0.3756
# Epoch 00001: accuracy improved from 0.36906 to 0.37560, saving model to gesturefinal.h5
# 27/75 [=========>....................] - ETA: 13:35 - loss: 1.3230 - accuracy: 0.3843
# Epoch 00001: accuracy improved from 0.37560 to 0.38426, saving model to gesturefinal.h5
# 28/75 [==========>...................] - ETA: 13:21 - loss: 1.3141 - accuracy: 0.3940
# Epoch 00001: accuracy improved from 0.38426 to 0.39397, saving model to gesturefinal.h5
# 29/75 [==========>...................] - ETA: 13:06 - loss: 1.3060 - accuracy: 0.4027
# Epoch 00001: accuracy improved from 0.39397 to 0.40275, saving model to gesturefinal.h5
# 30/75 [===========>..................] - ETA: 12:53 - loss: 1.2991 - accuracy: 0.4089
# Epoch 00001: accuracy improved from 0.40275 to 0.40885, saving model to gesturefinal.h5
# 31/75 [===========>..................] - ETA: 12:38 - loss: 1.2904 - accuracy: 0.4161
# Epoch 00001: accuracy improved from 0.40885 to 0.41608, saving model to gesturefinal.h5
# 32/75 [===========>..................] - ETA: 12:24 - loss: 1.2812 - accuracy: 0.4255
# Epoch 00001: accuracy improved from 0.41608 to 0.42554, saving model to gesturefinal.h5
# 33/75 [============>.................] - ETA: 12:11 - loss: 1.2723 - accuracy: 0.4335
# Epoch 00001: accuracy improved from 0.42554 to 0.43348, saving model to gesturefinal.h5
# 34/75 [============>.................] - ETA: 11:59 - loss: 1.2644 - accuracy: 0.4400
# Epoch 00001: accuracy improved from 0.43348 to 0.44003, saving model to gesturefinal.h5
# 35/75 [=============>................] - ETA: 11:44 - loss: 1.2544 - accuracy: 0.4473
# Epoch 00001: accuracy improved from 0.44003 to 0.44732, saving model to gesturefinal.h5
# 36/75 [=============>................] - ETA: 11:31 - loss: 1.2475 - accuracy: 0.4520
# Epoch 00001: accuracy improved from 0.44732 to 0.45204, saving model to gesturefinal.h5
# 37/75 [=============>................] - ETA: 11:16 - loss: 1.2388 - accuracy: 0.4582
# Epoch 00001: accuracy improved from 0.45204 to 0.45819, saving model to gesturefinal.h5
# 38/75 [==============>...............] - ETA: 11:00 - loss: 1.2311 - accuracy: 0.4626
# Epoch 00001: accuracy improved from 0.45819 to 0.46258, saving model to gesturefinal.h5
# 39/75 [==============>...............] - ETA: 10:43 - loss: 1.2201 - accuracy: 0.4704
# Epoch 00001: accuracy improved from 0.46258 to 0.47035, saving model to gesturefinal.h5
# 40/75 [===============>..............] - ETA: 10:26 - loss: 1.2110 - accuracy: 0.4760
# Epoch 00001: accuracy improved from 0.47035 to 0.47598, saving model to gesturefinal.h5
# 41/75 [===============>..............] - ETA: 10:09 - loss: 1.2029 - accuracy: 0.4819
# Epoch 00001: accuracy improved from 0.47598 to 0.48190, saving model to gesturefinal.h5
# 42/75 [===============>..............] - ETA: 9:51 - loss: 1.1949 - accuracy: 0.4860
# Epoch 00001: accuracy improved from 0.48190 to 0.48605, saving model to gesturefinal.h5
# 43/75 [================>.............] - ETA: 9:34 - loss: 1.1851 - accuracy: 0.4922
# Epoch 00001: accuracy improved from 0.48605 to 0.49219, saving model to gesturefinal.h5
# 44/75 [================>.............] - ETA: 9:16 - loss: 1.1749 - accuracy: 0.4980
# Epoch 00001: accuracy improved from 0.49219 to 0.49805, saving model to gesturefinal.h5
# 45/75 [=================>............] - ETA: 8:58 - loss: 1.1664 - accuracy: 0.5036
# Epoch 00001: accuracy improved from 0.49805 to 0.50365, saving model to gesturefinal.h5
# 46/75 [=================>............] - ETA: 8:41 - loss: 1.1579 - accuracy: 0.5092
# Epoch 00001: accuracy improved from 0.50365 to 0.50917, saving model to gesturefinal.h5
# 47/75 [=================>............] - ETA: 8:23 - loss: 1.1500 - accuracy: 0.5136
# Epoch 00001: accuracy improved from 0.50917 to 0.51363, saving model to gesturefinal.h5
# 48/75 [==================>...........] - ETA: 8:06 - loss: 1.1414 - accuracy: 0.5184
# Epoch 00001: accuracy improved from 0.51363 to 0.51839, saving model to gesturefinal.h5
# 49/75 [==================>...........] - ETA: 7:48 - loss: 1.1318 - accuracy: 0.5230
# Epoch 00001: accuracy improved from 0.51839 to 0.52296, saving model to gesturefinal.h5
# 50/75 [===================>..........] - ETA: 7:30 - loss: 1.1227 - accuracy: 0.5277
# Epoch 00001: accuracy improved from 0.52296 to 0.52766, saving model to gesturefinal.h5
# 51/75 [===================>..........] - ETA: 7:13 - loss: 1.1126 - accuracy: 0.5332
# Epoch 00001: accuracy improved from 0.52766 to 0.53324, saving model to gesturefinal.h5
# 52/75 [===================>..........] - ETA: 6:55 - loss: 1.1038 - accuracy: 0.5373
# Epoch 00001: accuracy improved from 0.53324 to 0.53726, saving model to gesturefinal.h5
# 53/75 [====================>.........] - ETA: 6:38 - loss: 1.0978 - accuracy: 0.5402
# Epoch 00001: accuracy improved from 0.53726 to 0.54024, saving model to gesturefinal.h5
# 54/75 [====================>.........] - ETA: 6:20 - loss: 1.0922 - accuracy: 0.5421
# Epoch 00001: accuracy improved from 0.54024 to 0.54210, saving model to gesturefinal.h5
# 55/75 [=====================>........] - ETA: 6:02 - loss: 1.0845 - accuracy: 0.5460
# Epoch 00001: accuracy improved from 0.54210 to 0.54602, saving model to gesturefinal.h5
# 56/75 [=====================>........] - ETA: 5:44 - loss: 1.0776 - accuracy: 0.5490
# Epoch 00001: accuracy improved from 0.54602 to 0.54897, saving model to gesturefinal.h5
# 57/75 [=====================>........] - ETA: 5:26 - loss: 1.0678 - accuracy: 0.5535
# Epoch 00001: accuracy improved from 0.54897 to 0.55345, saving model to gesturefinal.h5
# 58/75 [======================>.......] - ETA: 5:08 - loss: 1.0595 - accuracy: 0.5579
# Epoch 00001: accuracy improved from 0.55345 to 0.55792, saving model to gesturefinal.h5
# 59/75 [======================>.......] - ETA: 4:50 - loss: 1.0504 - accuracy: 0.5624
# Epoch 00001: accuracy improved from 0.55792 to 0.56237, saving model to gesturefinal.h5
# 60/75 [=======================>......] - ETA: 4:32 - loss: 1.0431 - accuracy: 0.5658
# Epoch 00001: accuracy improved from 0.56237 to 0.56576, saving model to gesturefinal.h5
# 61/75 [=======================>......] - ETA: 4:14 - loss: 1.0340 - accuracy: 0.5702
# Epoch 00001: accuracy improved from 0.56576 to 0.57018, saving model to gesturefinal.h5
# 62/75 [=======================>......] - ETA: 3:56 - loss: 1.0253 - accuracy: 0.5747
# Epoch 00001: accuracy improved from 0.57018 to 0.57472, saving model to gesturefinal.h5
# 63/75 [========================>.....] - ETA: 3:38 - loss: 1.0183 - accuracy: 0.5787
# Epoch 00001: accuracy improved from 0.57472 to 0.57875, saving model to gesturefinal.h5
# 64/75 [========================>.....] - ETA: 3:20 - loss: 1.0123 - accuracy: 0.5815
# Epoch 00001: accuracy improved from 0.57875 to 0.58154, saving model to gesturefinal.h5
# 65/75 [=========================>....] - ETA: 3:02 - loss: 1.0042 - accuracy: 0.5852
# Epoch 00001: accuracy improved from 0.58154 to 0.58522, saving model to gesturefinal.h5
# 66/75 [=========================>....] - ETA: 2:44 - loss: 0.9966 - accuracy: 0.5888
# Epoch 00001: accuracy improved from 0.58522 to 0.58878, saving model to gesturefinal.h5
# 67/75 [=========================>....] - ETA: 2:26 - loss: 0.9907 - accuracy: 0.5913
# Epoch 00001: accuracy improved from 0.58878 to 0.59130, saving model to gesturefinal.h5
# 68/75 [==========================>...] - ETA: 2:07 - loss: 0.9833 - accuracy: 0.5949
# Epoch 00001: accuracy improved from 0.59130 to 0.59490, saving model to gesturefinal.h5
# 69/75 [==========================>...] - ETA: 1:49 - loss: 0.9766 - accuracy: 0.5982
# Epoch 00001: accuracy improved from 0.59490 to 0.59817, saving model to gesturefinal.h5
# 70/75 [===========================>..] - ETA: 1:31 - loss: 0.9693 - accuracy: 0.6016
# Epoch 00001: accuracy improved from 0.59817 to 0.60156, saving model to gesturefinal.h5
# 71/75 [===========================>..] - ETA: 1:13 - loss: 0.9631 - accuracy: 0.6044
# Epoch 00001: accuracy improved from 0.60156 to 0.60442, saving model to gesturefinal.h5
# 72/75 [===========================>..] - ETA: 54s - loss: 0.9567 - accuracy: 0.6077
# Epoch 00001: accuracy improved from 0.60442 to 0.60775, saving model to gesturefinal.h5
# 73/75 [============================>.] - ETA: 36s - loss: 0.9503 - accuracy: 0.6106
# Epoch 00001: accuracy improved from 0.60775 to 0.61055, saving model to gesturefinal.h5
# 74/75 [============================>.] - ETA: 18s - loss: 0.9429 - accuracy: 0.6139
# Epoch 00001: accuracy improved from 0.61055 to 0.61391, saving model to gesturefinal.h5
# 75/75 [==============================] - ETA: 0s - loss: 0.9369 - accuracy: 0.6168
# Epoch 00001: accuracy improved from 0.61391 to 0.61677, saving model to gesturefinal.h5
# 75/75 [==============================] - 1687s 23s/step - loss: 0.9369 - accuracy: 0.6168 - val_loss: 0.4419 - val_accuracy: 0.8260
# Epoch 2/50
#  1/75 [..............................] - ETA: 22:28 - loss: 0.4470 - accuracy: 0.8359
# Epoch 00002: accuracy improved from 0.61677 to 0.83594, saving model to gesturefinal.h5
#  2/75 [..............................] - ETA: 21:40 - loss: 0.4251 - accuracy: 0.8477
# Epoch 00002: accuracy improved from 0.83594 to 0.84766, saving model to gesturefinal.h5
#  3/75 [>.............................] - ETA: 21:10 - loss: 0.4403 - accuracy: 0.8464
# Epoch 00002: accuracy did not improve from 0.84766
#  4/75 [>.............................] - ETA: 20:46 - loss: 0.4426 - accuracy: 0.8457
# Epoch 00002: accuracy did not improve from 0.84766
#  5/75 [=>............................] - ETA: 20:22 - loss: 0.4640 - accuracy: 0.8391
# Epoch 00002: accuracy did not improve from 0.84766
#  6/75 [=>............................] - ETA: 20:01 - loss: 0.4562 - accuracy: 0.8451
# Epoch 00002: accuracy did not improve from 0.84766
#  7/75 [=>............................] - ETA: 19:43 - loss: 0.4610 - accuracy: 0.8426
# Epoch 00002: accuracy did not improve from 0.84766
#  8/75 [==>...........................] - ETA: 19:22 - loss: 0.4514 - accuracy: 0.8438
# Epoch 00002: accuracy did not improve from 0.84766
#  9/75 [==>...........................] - ETA: 19:03 - loss: 0.4500 - accuracy: 0.8420
# Epoch 00002: accuracy did not improve from 0.84766
# 10/75 [===>..........................] - ETA: 18:48 - loss: 0.4477 - accuracy: 0.8438
# Epoch 00002: accuracy did not improve from 0.84766
# 11/75 [===>..........................] - ETA: 18:30 - loss: 0.4543 - accuracy: 0.8402
# Epoch 00002: accuracy did not improve from 0.84766
# 12/75 [===>..........................] - ETA: 18:14 - loss: 0.4549 - accuracy: 0.8405
# Epoch 00002: accuracy did not improve from 0.84766
# 13/75 [====>.........................] - ETA: 17:59 - loss: 0.4501 - accuracy: 0.8425
# Epoch 00002: accuracy did not improve from 0.84766
# 14/75 [====>.........................] - ETA: 17:42 - loss: 0.4553 - accuracy: 0.8398
# Epoch 00002: accuracy did not improve from 0.84766
# 15/75 [=====>........................] - ETA: 17:24 - loss: 0.4502 - accuracy: 0.8417
# Epoch 00002: accuracy did not improve from 0.84766
# 16/75 [=====>........................] - ETA: 17:05 - loss: 0.4476 - accuracy: 0.8438
# Epoch 00002: accuracy did not improve from 0.84766
# 17/75 [=====>........................] - ETA: 16:47 - loss: 0.4480 - accuracy: 0.8419
# Epoch 00002: accuracy did not improve from 0.84766
# 18/75 [======>.......................] - ETA: 16:29 - loss: 0.4467 - accuracy: 0.8420
# Epoch 00002: accuracy did not improve from 0.84766
# 19/75 [======>.......................] - ETA: 16:10 - loss: 0.4416 - accuracy: 0.8446
# Epoch 00002: accuracy did not improve from 0.84766
# 20/75 [=======>......................] - ETA: 15:53 - loss: 0.4394 - accuracy: 0.8438
# Epoch 00002: accuracy did not improve from 0.84766
# 21/75 [=======>......................] - ETA: 15:35 - loss: 0.4352 - accuracy: 0.8452
# Epoch 00002: accuracy did not improve from 0.84766
# 22/75 [=======>......................] - ETA: 15:17 - loss: 0.4311 - accuracy: 0.8477
# Epoch 00002: accuracy did not improve from 0.84766
# 23/75 [========>.....................] - ETA: 14:59 - loss: 0.4273 - accuracy: 0.8488
# Epoch 00002: accuracy improved from 0.84766 to 0.84885, saving model to gesturefinal.h5
# 24/75 [========>.....................] - ETA: 14:43 - loss: 0.4244 - accuracy: 0.8503
# Epoch 00002: accuracy improved from 0.84885 to 0.85026, saving model to gesturefinal.h5
# 25/75 [=========>....................] - ETA: 14:26 - loss: 0.4223 - accuracy: 0.8500
# Epoch 00002: accuracy did not improve from 0.85026
# 26/75 [=========>....................] - ETA: 14:09 - loss: 0.4207 - accuracy: 0.8507
# Epoch 00002: accuracy improved from 0.85026 to 0.85066, saving model to gesturefinal.h5
# 27/75 [=========>....................] - ETA: 13:53 - loss: 0.4192 - accuracy: 0.8501
# Epoch 00002: accuracy did not improve from 0.85066
# 28/75 [==========>...................] - ETA: 13:36 - loss: 0.4158 - accuracy: 0.8521
# Epoch 00002: accuracy improved from 0.85066 to 0.85212, saving model to gesturefinal.h5
# 29/75 [==========>...................] - ETA: 13:19 - loss: 0.4126 - accuracy: 0.8529
# Epoch 00002: accuracy improved from 0.85212 to 0.85291, saving model to gesturefinal.h5
# 30/75 [===========>..................] - ETA: 13:02 - loss: 0.4123 - accuracy: 0.8529
# Epoch 00002: accuracy did not improve from 0.85291
# 31/75 [===========>..................] - ETA: 12:44 - loss: 0.4121 - accuracy: 0.8521
# Epoch 00002: accuracy did not improve from 0.85291
# 32/75 [===========>..................] - ETA: 12:27 - loss: 0.4116 - accuracy: 0.8528
# Epoch 00002: accuracy did not improve from 0.85291
# 33/75 [============>.................] - ETA: 12:10 - loss: 0.4107 - accuracy: 0.8518
# Epoch 00002: accuracy did not improve from 0.85291
# 34/75 [============>.................] - ETA: 11:52 - loss: 0.4076 - accuracy: 0.8532
# Epoch 00002: accuracy improved from 0.85291 to 0.85317, saving model to gesturefinal.h5
# 35/75 [=============>................] - ETA: 11:36 - loss: 0.4039 - accuracy: 0.8551
# Epoch 00002: accuracy improved from 0.85317 to 0.85513, saving model to gesturefinal.h5
# 36/75 [=============>................] - ETA: 11:19 - loss: 0.4026 - accuracy: 0.8553
# Epoch 00002: accuracy improved from 0.85513 to 0.85525, saving model to gesturefinal.h5
# 37/75 [=============>................] - ETA: 11:02 - loss: 0.4007 - accuracy: 0.8560
# Epoch 00002: accuracy improved from 0.85525 to 0.85600, saving model to gesturefinal.h5
# 38/75 [==============>...............] - ETA: 10:45 - loss: 0.3967 - accuracy: 0.8579
# Epoch 00002: accuracy improved from 0.85600 to 0.85794, saving model to gesturefinal.h5
# 39/75 [==============>...............] - ETA: 10:27 - loss: 0.3964 - accuracy: 0.8588
# Epoch 00002: accuracy improved from 0.85794 to 0.85877, saving model to gesturefinal.h5
# 40/75 [===============>..............] - ETA: 10:10 - loss: 0.3966 - accuracy: 0.8582
# Epoch 00002: accuracy did not improve from 0.85877
# 41/75 [===============>..............] - ETA: 9:52 - loss: 0.3975 - accuracy: 0.8569
# Epoch 00002: accuracy did not improve from 0.85877
# 42/75 [===============>..............] - ETA: 9:34 - loss: 0.3953 - accuracy: 0.8579
# Epoch 00002: accuracy did not improve from 0.85877
# 43/75 [================>.............] - ETA: 9:17 - loss: 0.3952 - accuracy: 0.8579
# Epoch 00002: accuracy did not improve from 0.85877
# 44/75 [================>.............] - ETA: 8:59 - loss: 0.3937 - accuracy: 0.8585
# Epoch 00002: accuracy did not improve from 0.85877
# 45/75 [=================>............] - ETA: 8:42 - loss: 0.3953 - accuracy: 0.8575
# Epoch 00002: accuracy did not improve from 0.85877
# 46/75 [=================>............] - ETA: 8:24 - loss: 0.3947 - accuracy: 0.8578
# Epoch 00002: accuracy did not improve from 0.85877
# 47/75 [=================>............] - ETA: 8:07 - loss: 0.3924 - accuracy: 0.8590
# Epoch 00002: accuracy improved from 0.85877 to 0.85904, saving model to gesturefinal.h5
# 48/75 [==================>...........] - ETA: 7:49 - loss: 0.3934 - accuracy: 0.8586
# Epoch 00002: accuracy did not improve from 0.85904
# 49/75 [==================>...........] - ETA: 7:32 - loss: 0.3928 - accuracy: 0.8591
# Epoch 00002: accuracy improved from 0.85904 to 0.85906, saving model to gesturefinal.h5
# 50/75 [===================>..........] - ETA: 7:15 - loss: 0.3901 - accuracy: 0.8598
# Epoch 00002: accuracy improved from 0.85906 to 0.85984, saving model to gesturefinal.h5
# 51/75 [===================>..........] - ETA: 6:57 - loss: 0.3897 - accuracy: 0.8600
# Epoch 00002: accuracy improved from 0.85984 to 0.85999, saving model to gesturefinal.h5
# 52/75 [===================>..........] - ETA: 6:40 - loss: 0.3900 - accuracy: 0.8600
# Epoch 00002: accuracy did not improve from 0.85999
# 53/75 [====================>.........] - ETA: 6:23 - loss: 0.3884 - accuracy: 0.8604
# Epoch 00002: accuracy improved from 0.85999 to 0.86041, saving model to gesturefinal.h5
# 54/75 [====================>.........] - ETA: 6:05 - loss: 0.3879 - accuracy: 0.8604
# Epoch 00002: accuracy did not improve from 0.86041
# 55/75 [=====================>........] - ETA: 5:48 - loss: 0.3864 - accuracy: 0.8612
# Epoch 00002: accuracy improved from 0.86041 to 0.86122, saving model to gesturefinal.h5
# 56/75 [=====================>........] - ETA: 5:30 - loss: 0.3849 - accuracy: 0.8619
# Epoch 00002: accuracy improved from 0.86122 to 0.86189, saving model to gesturefinal.h5
# 57/75 [=====================>........] - ETA: 5:13 - loss: 0.3829 - accuracy: 0.8631
# Epoch 00002: accuracy improved from 0.86189 to 0.86308, saving model to gesturefinal.h5
# 58/75 [======================>.......] - ETA: 4:56 - loss: 0.3814 - accuracy: 0.8637
# Epoch 00002: accuracy improved from 0.86308 to 0.86369, saving model to gesturefinal.h5
# 59/75 [======================>.......] - ETA: 4:39 - loss: 0.3802 - accuracy: 0.8640
# Epoch 00002: accuracy improved from 0.86369 to 0.86401, saving model to gesturefinal.h5
# 60/75 [=======================>......] - ETA: 4:21 - loss: 0.3787 - accuracy: 0.8646
# Epoch 00002: accuracy improved from 0.86401 to 0.86458, saving model to gesturefinal.h5
# 61/75 [=======================>......] - ETA: 4:04 - loss: 0.3778 - accuracy: 0.8651
# Epoch 00002: accuracy improved from 0.86458 to 0.86514, saving model to gesturefinal.h5
# 62/75 [=======================>......] - ETA: 3:46 - loss: 0.3764 - accuracy: 0.8652
# Epoch 00002: accuracy improved from 0.86514 to 0.86517, saving model to gesturefinal.h5
# 63/75 [========================>.....] - ETA: 3:29 - loss: 0.3749 - accuracy: 0.8658
# Epoch 00002: accuracy improved from 0.86517 to 0.86582, saving model to gesturefinal.h5
# 64/75 [========================>.....] - ETA: 3:12 - loss: 0.3741 - accuracy: 0.8656
# Epoch 00002: accuracy did not improve from 0.86582
# 65/75 [=========================>....] - ETA: 2:54 - loss: 0.3752 - accuracy: 0.8654
# Epoch 00002: accuracy did not improve from 0.86582
# 66/75 [=========================>....] - ETA: 2:37 - loss: 0.3740 - accuracy: 0.8658
# Epoch 00002: accuracy did not improve from 0.86582
# 67/75 [=========================>....] - ETA: 2:19 - loss: 0.3725 - accuracy: 0.8663
# Epoch 00002: accuracy improved from 0.86582 to 0.86625, saving model to gesturefinal.h5
# 68/75 [==========================>...] - ETA: 2:02 - loss: 0.3705 - accuracy: 0.8672
# Epoch 00002: accuracy improved from 0.86625 to 0.86719, saving model to gesturefinal.h5
# 69/75 [==========================>...] - ETA: 1:44 - loss: 0.3691 - accuracy: 0.8674
# Epoch 00002: accuracy improved from 0.86719 to 0.86741, saving model to gesturefinal.h5
# 70/75 [===========================>..] - ETA: 1:27 - loss: 0.3694 - accuracy: 0.8673
# Epoch 00002: accuracy did not improve from 0.86741
# 71/75 [===========================>..] - ETA: 1:09 - loss: 0.3696 - accuracy: 0.8676
# Epoch 00002: accuracy improved from 0.86741 to 0.86763, saving model to gesturefinal.h5
# 72/75 [===========================>..] - ETA: 52s - loss: 0.3680 - accuracy: 0.8683
# Epoch 00002: accuracy improved from 0.86763 to 0.86827, saving model to gesturefinal.h5
# 73/75 [============================>.] - ETA: 34s - loss: 0.3666 - accuracy: 0.8687
# Epoch 00002: accuracy improved from 0.86827 to 0.86869, saving model to gesturefinal.h5
# 74/75 [============================>.] - ETA: 17s - loss: 0.3654 - accuracy: 0.8692
# Epoch 00002: accuracy improved from 0.86869 to 0.86919, saving model to gesturefinal.h5
# 75/75 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8699
# Epoch 00002: accuracy improved from 0.86919 to 0.86990, saving model to gesturefinal.h5
# 75/75 [==============================] - 1616s 22s/step - loss: 0.3643 - accuracy: 0.8699 - val_loss: 0.1736 - val_accuracy: 0.9401
# Epoch 3/50
#  1/75 [..............................] - ETA: 22:29 - loss: 0.3053 - accuracy: 0.8828
# Epoch 00003: accuracy improved from 0.86990 to 0.88281, saving model to gesturefinal.h5
#  2/75 [..............................] - ETA: 21:09 - loss: 0.2824 - accuracy: 0.8984
# Epoch 00003: accuracy improved from 0.88281 to 0.89844, saving model to gesturefinal.h5
#  3/75 [>.............................] - ETA: 21:00 - loss: 0.2972 - accuracy: 0.8880
# Epoch 00003: accuracy did not improve from 0.89844
#  4/75 [>.............................] - ETA: 20:35 - loss: 0.2603 - accuracy: 0.9062
# Epoch 00003: accuracy improved from 0.89844 to 0.90625, saving model to gesturefinal.h5
#  5/75 [=>............................] - ETA: 20:19 - loss: 0.2713 - accuracy: 0.9031
# Epoch 00003: accuracy did not improve from 0.90625
#  6/75 [=>............................] - ETA: 20:02 - loss: 0.2852 - accuracy: 0.8997
# Epoch 00003: accuracy did not improve from 0.90625
#  7/75 [=>............................] - ETA: 19:40 - loss: 0.2843 - accuracy: 0.9029
# Epoch 00003: accuracy did not improve from 0.90625
#  8/75 [==>...........................] - ETA: 19:23 - loss: 0.2796 - accuracy: 0.9072
# Epoch 00003: accuracy improved from 0.90625 to 0.90723, saving model to gesturefinal.h5
#  9/75 [==>...........................] - ETA: 19:08 - loss: 0.2742 - accuracy: 0.9089
# Epoch 00003: accuracy improved from 0.90723 to 0.90885, saving model to gesturefinal.h5
# 10/75 [===>..........................] - ETA: 18:53 - loss: 0.2780 - accuracy: 0.9047
# Epoch 00003: accuracy did not improve from 0.90885
# 11/75 [===>..........................] - ETA: 18:33 - loss: 0.2730 - accuracy: 0.9062
# Epoch 00003: accuracy did not improve from 0.90885
# 12/75 [===>..........................] - ETA: 18:14 - loss: 0.2697 - accuracy: 0.9089
# Epoch 00003: accuracy did not improve from 0.90885
# 13/75 [====>.........................] - ETA: 17:57 - loss: 0.2668 - accuracy: 0.9123
# Epoch 00003: accuracy improved from 0.90885 to 0.91226, saving model to gesturefinal.h5
# 14/75 [====>.........................] - ETA: 17:42 - loss: 0.2657 - accuracy: 0.9124
# Epoch 00003: accuracy improved from 0.91226 to 0.91239, saving model to gesturefinal.h5
# 15/75 [=====>........................] - ETA: 17:27 - loss: 0.2633 - accuracy: 0.9125
# Epoch 00003: accuracy improved from 0.91239 to 0.91250, saving model to gesturefinal.h5
# 16/75 [=====>........................] - ETA: 17:11 - loss: 0.2590 - accuracy: 0.9141
# Epoch 00003: accuracy improved from 0.91250 to 0.91406, saving model to gesturefinal.h5
# 17/75 [=====>........................] - ETA: 16:54 - loss: 0.2581 - accuracy: 0.9141
# Epoch 00003: accuracy did not improve from 0.91406
# 18/75 [======>.......................] - ETA: 16:36 - loss: 0.2577 - accuracy: 0.9149
# Epoch 00003: accuracy improved from 0.91406 to 0.91493, saving model to gesturefinal.h5
# 19/75 [======>.......................] - ETA: 16:20 - loss: 0.2543 - accuracy: 0.9169
# Epoch 00003: accuracy improved from 0.91493 to 0.91694, saving model to gesturefinal.h5
# 20/75 [=======>......................] - ETA: 16:03 - loss: 0.2575 - accuracy: 0.9148
# Epoch 00003: accuracy did not improve from 0.91694
# 21/75 [=======>......................] - ETA: 15:44 - loss: 0.2554 - accuracy: 0.9156
# Epoch 00003: accuracy did not improve from 0.91694
# 22/75 [=======>......................] - ETA: 15:27 - loss: 0.2527 - accuracy: 0.9162
# Epoch 00003: accuracy did not improve from 0.91694
# 23/75 [========>.....................] - ETA: 15:09 - loss: 0.2511 - accuracy: 0.9164
# Epoch 00003: accuracy did not improve from 0.91694
# 24/75 [========>.....................] - ETA: 14:52 - loss: 0.2509 - accuracy: 0.9157
# Epoch 00003: accuracy did not improve from 0.91694
# 25/75 [=========>....................] - ETA: 14:34 - loss: 0.2489 - accuracy: 0.9156
# Epoch 00003: accuracy did not improve from 0.91694
# 26/75 [=========>....................] - ETA: 14:15 - loss: 0.2469 - accuracy: 0.9174
# Epoch 00003: accuracy improved from 0.91694 to 0.91737, saving model to gesturefinal.h5
# 27/75 [=========>....................] - ETA: 13:58 - loss: 0.2491 - accuracy: 0.9161
# Epoch 00003: accuracy did not improve from 0.91737
# 28/75 [==========>...................] - ETA: 13:40 - loss: 0.2489 - accuracy: 0.9166
# Epoch 00003: accuracy did not improve from 0.91737
# 29/75 [==========>...................] - ETA: 13:22 - loss: 0.2492 - accuracy: 0.9168
# Epoch 00003: accuracy did not improve from 0.91737
# 30/75 [===========>..................] - ETA: 13:04 - loss: 0.2489 - accuracy: 0.9164
# Epoch 00003: accuracy did not improve from 0.91737
# 31/75 [===========>..................] - ETA: 12:47 - loss: 0.2481 - accuracy: 0.9171
# Epoch 00003: accuracy did not improve from 0.91737
# 32/75 [===========>..................] - ETA: 12:29 - loss: 0.2523 - accuracy: 0.9148
# Epoch 00003: accuracy did not improve from 0.91737
# 33/75 [============>.................] - ETA: 12:11 - loss: 0.2521 - accuracy: 0.9150
# Epoch 00003: accuracy did not improve from 0.91737
# 34/75 [============>.................] - ETA: 11:54 - loss: 0.2531 - accuracy: 0.9143
# Epoch 00003: accuracy did not improve from 0.91737
# 35/75 [=============>................] - ETA: 11:37 - loss: 0.2516 - accuracy: 0.9145
# Epoch 00003: accuracy did not improve from 0.91737
# 36/75 [=============>................] - ETA: 11:19 - loss: 0.2531 - accuracy: 0.9138
# Epoch 00003: accuracy did not improve from 0.91737
# 37/75 [=============>................] - ETA: 11:01 - loss: 0.2531 - accuracy: 0.9143
# Epoch 00003: accuracy did not improve from 0.91737
# 38/75 [==============>...............] - ETA: 10:43 - loss: 0.2535 - accuracy: 0.9143
# Epoch 00003: accuracy did not improve from 0.91737
# 39/75 [==============>...............] - ETA: 10:26 - loss: 0.2547 - accuracy: 0.9133
# Epoch 00003: accuracy did not improve from 0.91737
# 40/75 [===============>..............] - ETA: 10:08 - loss: 0.2555 - accuracy: 0.9125
# Epoch 00003: accuracy did not improve from 0.91737
# 41/75 [===============>..............] - ETA: 9:51 - loss: 0.2554 - accuracy: 0.9122
# Epoch 00003: accuracy did not improve from 0.91737
# 42/75 [===============>..............] - ETA: 9:33 - loss: 0.2563 - accuracy: 0.9122
# Epoch 00003: accuracy did not improve from 0.91737
# 43/75 [================>.............] - ETA: 9:16 - loss: 0.2584 - accuracy: 0.9112
# Epoch 00003: accuracy did not improve from 0.91737
# 44/75 [================>.............] - ETA: 8:58 - loss: 0.2607 - accuracy: 0.9105
# Epoch 00003: accuracy did not improve from 0.91737
# 45/75 [=================>............] - ETA: 8:41 - loss: 0.2607 - accuracy: 0.9101
# Epoch 00003: accuracy did not improve from 0.91737
# 46/75 [=================>............] - ETA: 8:23 - loss: 0.2590 - accuracy: 0.9107
# Epoch 00003: accuracy did not improve from 0.91737
# 47/75 [=================>............] - ETA: 8:06 - loss: 0.2588 - accuracy: 0.9104
# Epoch 00003: accuracy did not improve from 0.91737
# 48/75 [==================>...........] - ETA: 7:48 - loss: 0.2591 - accuracy: 0.9102
# Epoch 00003: accuracy did not improve from 0.91737
# 49/75 [==================>...........] - ETA: 7:31 - loss: 0.2592 - accuracy: 0.9099
# Epoch 00003: accuracy did not improve from 0.91737
# 50/75 [===================>..........] - ETA: 7:13 - loss: 0.2597 - accuracy: 0.9097
# Epoch 00003: accuracy did not improve from 0.91737
# 51/75 [===================>..........] - ETA: 6:56 - loss: 0.2604 - accuracy: 0.9092
# Epoch 00003: accuracy did not improve from 0.91737
# 52/75 [===================>..........] - ETA: 6:39 - loss: 0.2602 - accuracy: 0.9097
# Epoch 00003: accuracy did not improve from 0.91737
# 53/75 [====================>.........] - ETA: 6:21 - loss: 0.2607 - accuracy: 0.9092
# Epoch 00003: accuracy did not improve from 0.91737
# 54/75 [====================>.........] - ETA: 6:04 - loss: 0.2603 - accuracy: 0.9090
# Epoch 00003: accuracy did not improve from 0.91737
# 55/75 [=====================>........] - ETA: 5:46 - loss: 0.2605 - accuracy: 0.9087
# Epoch 00003: accuracy did not improve from 0.91737
# 56/75 [=====================>........] - ETA: 5:29 - loss: 0.2603 - accuracy: 0.9089
# Epoch 00003: accuracy did not improve from 0.91737
# 57/75 [=====================>........] - ETA: 5:12 - loss: 0.2605 - accuracy: 0.9090
# Epoch 00003: accuracy did not improve from 0.91737
# 58/75 [======================>.......] - ETA: 4:55 - loss: 0.2592 - accuracy: 0.9092
# Epoch 00003: accuracy did not improve from 0.91737
# 59/75 [======================>.......] - ETA: 4:37 - loss: 0.2594 - accuracy: 0.9089
# Epoch 00003: accuracy did not improve from 0.91737
# 60/75 [=======================>......] - ETA: 4:20 - loss: 0.2603 - accuracy: 0.9078
# Epoch 00003: accuracy did not improve from 0.91737
# 61/75 [=======================>......] - ETA: 4:03 - loss: 0.2597 - accuracy: 0.9082
# Epoch 00003: accuracy did not improve from 0.91737
# 62/75 [=======================>......] - ETA: 3:45 - loss: 0.2585 - accuracy: 0.9089
# Epoch 00003: accuracy did not improve from 0.91737
# 63/75 [========================>.....] - ETA: 3:28 - loss: 0.2579 - accuracy: 0.9090
# Epoch 00003: accuracy did not improve from 0.91737
# 64/75 [========================>.....] - ETA: 3:10 - loss: 0.2571 - accuracy: 0.9092
# Epoch 00003: accuracy did not improve from 0.91737
# 65/75 [=========================>....] - ETA: 2:53 - loss: 0.2568 - accuracy: 0.9095
# Epoch 00003: accuracy did not improve from 0.91737
# 66/75 [=========================>....] - ETA: 2:36 - loss: 0.2563 - accuracy: 0.9098
# Epoch 00003: accuracy did not improve from 0.91737
# 67/75 [=========================>....] - ETA: 2:18 - loss: 0.2567 - accuracy: 0.9097
# Epoch 00003: accuracy did not improve from 0.91737
# 68/75 [==========================>...] - ETA: 2:01 - loss: 0.2565 - accuracy: 0.9098
# Epoch 00003: accuracy did not improve from 0.91737
# 69/75 [==========================>...] - ETA: 1:44 - loss: 0.2570 - accuracy: 0.9095
# Epoch 00003: accuracy did not improve from 0.91737
# 70/75 [===========================>..] - ETA: 1:26 - loss: 0.2572 - accuracy: 0.9096
# Epoch 00003: accuracy did not improve from 0.91737
# 71/75 [===========================>..] - ETA: 1:09 - loss: 0.2565 - accuracy: 0.9099
# Epoch 00003: accuracy did not improve from 0.91737
# 72/75 [===========================>..] - ETA: 52s - loss: 0.2560 - accuracy: 0.9103
# Epoch 00003: accuracy did not improve from 0.91737
# 73/75 [============================>.] - ETA: 34s - loss: 0.2568 - accuracy: 0.9096
# Epoch 00003: accuracy did not improve from 0.91737
# 74/75 [============================>.] - ETA: 17s - loss: 0.2561 - accuracy: 0.9098
# Epoch 00003: accuracy did not improve from 0.91737
# 75/75 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9104
# Epoch 00003: accuracy did not improve from 0.91737
# 75/75 [==============================] - 1609s 21s/step - loss: 0.2547 - accuracy: 0.9104 - val_loss: 0.1826 - val_accuracy: 0.9327
# Epoch 4/50
#  1/75 [..............................] - ETA: 22:24 - loss: 0.3126 - accuracy: 0.8594
# Epoch 00004: accuracy did not improve from 0.91737
#  2/75 [..............................] - ETA: 20:39 - loss: 0.2763 - accuracy: 0.8906
# Epoch 00004: accuracy did not improve from 0.91737
#  3/75 [>.............................] - ETA: 20:33 - loss: 0.2916 - accuracy: 0.8906
# Epoch 00004: accuracy did not improve from 0.91737
#  4/75 [>.............................] - ETA: 20:24 - loss: 0.2663 - accuracy: 0.9043
# Epoch 00004: accuracy did not improve from 0.91737
#  5/75 [=>............................] - ETA: 20:13 - loss: 0.2638 - accuracy: 0.9016
# Epoch 00004: accuracy did not improve from 0.91737
#  6/75 [=>............................] - ETA: 19:57 - loss: 0.2457 - accuracy: 0.9102
# Epoch 00004: accuracy did not improve from 0.91737
#  7/75 [=>............................] - ETA: 19:43 - loss: 0.2407 - accuracy: 0.9129
# Epoch 00004: accuracy did not improve from 0.91737
#  8/75 [==>...........................] - ETA: 19:22 - loss: 0.2373 - accuracy: 0.9150
# Epoch 00004: accuracy did not improve from 0.91737
#  9/75 [==>...........................] - ETA: 19:03 - loss: 0.2293 - accuracy: 0.9210
# Epoch 00004: accuracy improved from 0.91737 to 0.92101, saving model to gesturefinal.h5
# 10/75 [===>..........................] - ETA: 18:50 - loss: 0.2241 - accuracy: 0.9242
# Epoch 00004: accuracy improved from 0.92101 to 0.92422, saving model to gesturefinal.h5
# 11/75 [===>..........................] - ETA: 18:35 - loss: 0.2189 - accuracy: 0.9247
# Epoch 00004: accuracy improved from 0.92422 to 0.92472, saving model to gesturefinal.h5
# 12/75 [===>..........................] - ETA: 18:20 - loss: 0.2162 - accuracy: 0.9271
# Epoch 00004: accuracy improved from 0.92472 to 0.92708, saving model to gesturefinal.h5
# 13/75 [====>.........................] - ETA: 18:04 - loss: 0.2243 - accuracy: 0.9231
# Epoch 00004: accuracy did not improve from 0.92708
# 14/75 [====>.........................] - ETA: 17:46 - loss: 0.2210 - accuracy: 0.9247
# Epoch 00004: accuracy did not improve from 0.92708
# 15/75 [=====>........................] - ETA: 17:30 - loss: 0.2221 - accuracy: 0.9245
# Epoch 00004: accuracy did not improve from 0.92708
# 16/75 [=====>........................] - ETA: 17:13 - loss: 0.2230 - accuracy: 0.9229
# Epoch 00004: accuracy did not improve from 0.92708
# 17/75 [=====>........................] - ETA: 16:55 - loss: 0.2237 - accuracy: 0.9214
# Epoch 00004: accuracy did not improve from 0.92708
# 18/75 [======>.......................] - ETA: 16:38 - loss: 0.2192 - accuracy: 0.9236
# Epoch 00004: accuracy did not improve from 0.92708
# 19/75 [======>.......................] - ETA: 16:19 - loss: 0.2183 - accuracy: 0.9227
# Epoch 00004: accuracy did not improve from 0.92708
# 20/75 [=======>......................] - ETA: 16:01 - loss: 0.2168 - accuracy: 0.9230
# Epoch 00004: accuracy did not improve from 0.92708
# 21/75 [=======>......................] - ETA: 15:43 - loss: 0.2222 - accuracy: 0.9211
# Epoch 00004: accuracy did not improve from 0.92708
# 22/75 [=======>......................] - ETA: 15:24 - loss: 0.2205 - accuracy: 0.9222
# Epoch 00004: accuracy did not improve from 0.92708
# 23/75 [========>.....................] - ETA: 15:08 - loss: 0.2248 - accuracy: 0.9202
# Epoch 00004: accuracy did not improve from 0.92708
# 24/75 [========>.....................] - ETA: 14:51 - loss: 0.2250 - accuracy: 0.9199
# Epoch 00004: accuracy did not improve from 0.92708
# 25/75 [=========>....................] - ETA: 14:34 - loss: 0.2254 - accuracy: 0.9197
# Epoch 00004: accuracy did not improve from 0.92708
# 26/75 [=========>....................] - ETA: 14:16 - loss: 0.2274 - accuracy: 0.9180
# Epoch 00004: accuracy did not improve from 0.92708
# 27/75 [=========>....................] - ETA: 13:59 - loss: 0.2271 - accuracy: 0.9170
# Epoch 00004: accuracy did not improve from 0.92708
# 28/75 [==========>...................] - ETA: 13:42 - loss: 0.2275 - accuracy: 0.9171
# Epoch 00004: accuracy did not improve from 0.92708
# 29/75 [==========>...................] - ETA: 13:25 - loss: 0.2265 - accuracy: 0.9176
# Epoch 00004: accuracy did not improve from 0.92708
# 30/75 [===========>..................] - ETA: 13:08 - loss: 0.2257 - accuracy: 0.9177
# Epoch 00004: accuracy did not improve from 0.92708
# 31/75 [===========>..................] - ETA: 12:50 - loss: 0.2264 - accuracy: 0.9176
# Epoch 00004: accuracy did not improve from 0.92708
# 32/75 [===========>..................] - ETA: 12:32 - loss: 0.2255 - accuracy: 0.9182
# Epoch 00004: accuracy did not improve from 0.92708
# 33/75 [============>.................] - ETA: 12:15 - loss: 0.2241 - accuracy: 0.9183
# Epoch 00004: accuracy did not improve from 0.92708
# 34/75 [============>.................] - ETA: 11:57 - loss: 0.2226 - accuracy: 0.9187
# Epoch 00004: accuracy did not improve from 0.92708
# 35/75 [=============>................] - ETA: 11:39 - loss: 0.2235 - accuracy: 0.9185
# Epoch 00004: accuracy did not improve from 0.92708
# 36/75 [=============>................] - ETA: 11:22 - loss: 0.2226 - accuracy: 0.9184
# Epoch 00004: accuracy did not improve from 0.92708
# 37/75 [=============>................] - ETA: 11:05 - loss: 0.2230 - accuracy: 0.9183
# Epoch 00004: accuracy did not improve from 0.92708
# 38/75 [==============>...............] - ETA: 10:48 - loss: 0.2208 - accuracy: 0.9192
# Epoch 00004: accuracy did not improve from 0.92708
# 39/75 [==============>...............] - ETA: 10:30 - loss: 0.2197 - accuracy: 0.9199
# Epoch 00004: accuracy did not improve from 0.92708
# 40/75 [===============>..............] - ETA: 10:13 - loss: 0.2196 - accuracy: 0.9201
# Epoch 00004: accuracy did not improve from 0.92708
# 41/75 [===============>..............] - ETA: 9:55 - loss: 0.2211 - accuracy: 0.9200
# Epoch 00004: accuracy did not improve from 0.92708
# 42/75 [===============>..............] - ETA: 9:38 - loss: 0.2208 - accuracy: 0.9198
# Epoch 00004: accuracy did not improve from 0.92708
# 43/75 [================>.............] - ETA: 9:20 - loss: 0.2211 - accuracy: 0.9193
# Epoch 00004: accuracy did not improve from 0.92708
# 44/75 [================>.............] - ETA: 9:03 - loss: 0.2216 - accuracy: 0.9187
# Epoch 00004: accuracy did not improve from 0.92708
# 45/75 [=================>............] - ETA: 8:45 - loss: 0.2240 - accuracy: 0.9182
# Epoch 00004: accuracy did not improve from 0.92708
# 46/75 [=================>............] - ETA: 8:28 - loss: 0.2242 - accuracy: 0.9181
# Epoch 00004: accuracy did not improve from 0.92708
# 47/75 [=================>............] - ETA: 8:10 - loss: 0.2241 - accuracy: 0.9181
# Epoch 00004: accuracy did not improve from 0.92708
# 48/75 [==================>...........] - ETA: 7:53 - loss: 0.2246 - accuracy: 0.9178
# Epoch 00004: accuracy did not improve from 0.92708
# 49/75 [==================>...........] - ETA: 7:36 - loss: 0.2243 - accuracy: 0.9179
# Epoch 00004: accuracy did not improve from 0.92708
# 50/75 [===================>..........] - ETA: 7:18 - loss: 0.2233 - accuracy: 0.9180
# Epoch 00004: accuracy did not improve from 0.92708
# 51/75 [===================>..........] - ETA: 7:01 - loss: 0.2236 - accuracy: 0.9182
# Epoch 00004: accuracy did not improve from 0.92708
# 52/75 [===================>..........] - ETA: 6:43 - loss: 0.2240 - accuracy: 0.9178
# Epoch 00004: accuracy did not improve from 0.92708
# 53/75 [====================>.........] - ETA: 6:26 - loss: 0.2224 - accuracy: 0.9185
# Epoch 00004: accuracy did not improve from 0.92708
# 54/75 [====================>.........] - ETA: 6:08 - loss: 0.2232 - accuracy: 0.9184
# Epoch 00004: accuracy did not improve from 0.92708
# 55/75 [=====================>........] - ETA: 5:50 - loss: 0.2233 - accuracy: 0.9185
# Epoch 00004: accuracy did not improve from 0.92708
# 56/75 [=====================>........] - ETA: 5:33 - loss: 0.2222 - accuracy: 0.9192
# Epoch 00004: accuracy did not improve from 0.92708
# 57/75 [=====================>........] - ETA: 5:15 - loss: 0.2206 - accuracy: 0.9198
# Epoch 00004: accuracy did not improve from 0.92708
# 58/75 [======================>.......] - ETA: 4:58 - loss: 0.2207 - accuracy: 0.9195
# Epoch 00004: accuracy did not improve from 0.92708
# 59/75 [======================>.......] - ETA: 4:40 - loss: 0.2203 - accuracy: 0.9192
# Epoch 00004: accuracy did not improve from 0.92708
# 60/75 [=======================>......] - ETA: 4:23 - loss: 0.2205 - accuracy: 0.9191
# Epoch 00004: accuracy did not improve from 0.92708
# 61/75 [=======================>......] - ETA: 4:05 - loss: 0.2195 - accuracy: 0.9198
# Epoch 00004: accuracy did not improve from 0.92708
# 62/75 [=======================>......] - ETA: 3:48 - loss: 0.2188 - accuracy: 0.9202
# Epoch 00004: accuracy did not improve from 0.92708
# 63/75 [========================>.....] - ETA: 3:30 - loss: 0.2182 - accuracy: 0.9205
# Epoch 00004: accuracy did not improve from 0.92708
# 64/75 [========================>.....] - ETA: 3:12 - loss: 0.2182 - accuracy: 0.9203
# Epoch 00004: accuracy did not improve from 0.92708
# 65/75 [=========================>....] - ETA: 2:55 - loss: 0.2190 - accuracy: 0.9201
# Epoch 00004: accuracy did not improve from 0.92708
# 66/75 [=========================>....] - ETA: 2:37 - loss: 0.2183 - accuracy: 0.9205
# Epoch 00004: accuracy did not improve from 0.92708
# 67/75 [=========================>....] - ETA: 2:20 - loss: 0.2171 - accuracy: 0.9211
# Epoch 00004: accuracy did not improve from 0.92708
# 68/75 [==========================>...] - ETA: 2:02 - loss: 0.2165 - accuracy: 0.9214
# Epoch 00004: accuracy did not improve from 0.92708
# 69/75 [==========================>...] - ETA: 1:45 - loss: 0.2165 - accuracy: 0.9214
# Epoch 00004: accuracy did not improve from 0.92708
# 70/75 [===========================>..] - ETA: 1:27 - loss: 0.2149 - accuracy: 0.9219
# Epoch 00004: accuracy did not improve from 0.92708
# 71/75 [===========================>..] - ETA: 1:10 - loss: 0.2143 - accuracy: 0.9222
# Epoch 00004: accuracy did not improve from 0.92708
# 72/75 [===========================>..] - ETA: 52s - loss: 0.2135 - accuracy: 0.9229
# Epoch 00004: accuracy did not improve from 0.92708
# 73/75 [============================>.] - ETA: 35s - loss: 0.2129 - accuracy: 0.9232
# Epoch 00004: accuracy did not improve from 0.92708
# 74/75 [============================>.] - ETA: 17s - loss: 0.2129 - accuracy: 0.9228
# Epoch 00004: accuracy did not improve from 0.92708
# 75/75 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.9226
# Epoch 00004: accuracy did not improve from 0.92708
# 75/75 [==============================] - 1626s 22s/step - loss: 0.2135 - accuracy: 0.9226 - val_loss: 0.1643 - val_accuracy: 0.9497
# Epoch 5/50
#  1/75 [..............................] - ETA: 22:42 - loss: 0.2763 - accuracy: 0.8984
# Epoch 00005: accuracy did not improve from 0.92708
#  2/75 [..............................] - ETA: 21:07 - loss: 0.2517 - accuracy: 0.9062
# Epoch 00005: accuracy did not improve from 0.92708
#  3/75 [>.............................] - ETA: 20:50 - loss: 0.2477 - accuracy: 0.9115
# Epoch 00005: accuracy did not improve from 0.92708
#  4/75 [>.............................] - ETA: 20:42 - loss: 0.2317 - accuracy: 0.9199
# Epoch 00005: accuracy did not improve from 0.92708
#  5/75 [=>............................] - ETA: 20:28 - loss: 0.2212 - accuracy: 0.9250
# Epoch 00005: accuracy did not improve from 0.92708
#  6/75 [=>............................] - ETA: 20:10 - loss: 0.2094 - accuracy: 0.9297
# Epoch 00005: accuracy improved from 0.92708 to 0.92969, saving model to gesturefinal.h5
#  7/75 [=>............................] - ETA: 19:59 - loss: 0.1989 - accuracy: 0.9330
# Epoch 00005: accuracy improved from 0.92969 to 0.93304, saving model to gesturefinal.h5
#  8/75 [==>...........................] - ETA: 19:43 - loss: 0.1925 - accuracy: 0.9365
# Epoch 00005: accuracy improved from 0.93304 to 0.93652, saving model to gesturefinal.h5
#  9/75 [==>...........................] - ETA: 19:26 - loss: 0.1935 - accuracy: 0.9358
# Epoch 00005: accuracy did not improve from 0.93652
# 10/75 [===>..........................] - ETA: 19:06 - loss: 0.1931 - accuracy: 0.9352
# Epoch 00005: accuracy did not improve from 0.93652
# 11/75 [===>..........................] - ETA: 18:48 - loss: 0.1930 - accuracy: 0.9347
# Epoch 00005: accuracy did not improve from 0.93652
# 12/75 [===>..........................] - ETA: 18:31 - loss: 0.1876 - accuracy: 0.9375
# Epoch 00005: accuracy improved from 0.93652 to 0.93750, saving model to gesturefinal.h5
# ...
# 36/75 [=============>................] - ETA: 11:15 - loss: 0.0740 - accuracy: 0.9714
# Epoch 00049: accuracy did not improve from 1.00000
# 37/75 [=============>................] - ETA: 10:57 - loss: 0.0744 - accuracy: 0.9713
# Epoch 00049: accuracy did not improve from 1.00000
# 38/75 [==============>...............] - ETA: 10:40 - loss: 0.0732 - accuracy: 0.9718
# Epoch 00049: accuracy did not improve from 1.00000
# 39/75 [==============>...............] - ETA: 10:23 - loss: 0.0747 - accuracy: 0.9710
# Epoch 00049: accuracy did not improve from 1.00000
# 40/75 [===============>..............] - ETA: 10:06 - loss: 0.0745 - accuracy: 0.9711
# Epoch 00049: accuracy did not improve from 1.00000
# 41/75 [===============>..............] - ETA: 9:48 - loss: 0.0745 - accuracy: 0.9712
# Epoch 00049: accuracy did not improve from 1.00000
# 42/75 [===============>..............] - ETA: 9:31 - loss: 0.0748 - accuracy: 0.9710
# Epoch 00049: accuracy did not improve from 1.00000
# 43/75 [================>.............] - ETA: 9:14 - loss: 0.0744 - accuracy: 0.9711
# Epoch 00049: accuracy did not improve from 1.00000
# 44/75 [================>.............] - ETA: 8:56 - loss: 0.0753 - accuracy: 0.9711
# Epoch 00049: accuracy did not improve from 1.00000
# 45/75 [=================>............] - ETA: 8:39 - loss: 0.0754 - accuracy: 0.9707
# Epoch 00049: accuracy did not improve from 1.00000
# 46/75 [=================>............] - ETA: 8:22 - loss: 0.0745 - accuracy: 0.9713
# Epoch 00049: accuracy did not improve from 1.00000
# 47/75 [=================>............] - ETA: 8:05 - loss: 0.0748 - accuracy: 0.9712
# Epoch 00049: accuracy did not improve from 1.00000
# 48/75 [==================>...........] - ETA: 7:48 - loss: 0.0746 - accuracy: 0.9714
# Epoch 00049: accuracy did not improve from 1.00000
# 49/75 [==================>...........] - ETA: 7:30 - loss: 0.0738 - accuracy: 0.9716
# Epoch 00049: accuracy did not improve from 1.00000
# 50/75 [===================>..........] - ETA: 7:13 - loss: 0.0731 - accuracy: 0.9720
# Epoch 00049: accuracy did not improve from 1.00000
# 51/75 [===================>..........] - ETA: 6:55 - loss: 0.0734 - accuracy: 0.9723
# Epoch 00049: accuracy did not improve from 1.00000
# 52/75 [===================>..........] - ETA: 6:38 - loss: 0.0726 - accuracy: 0.9727
# Epoch 00049: accuracy did not improve from 1.00000
# 53/75 [====================>.........] - ETA: 6:21 - loss: 0.0725 - accuracy: 0.9729
# Epoch 00049: accuracy did not improve from 1.00000
# 54/75 [====================>.........] - ETA: 6:04 - loss: 0.0736 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 55/75 [=====================>........] - ETA: 5:46 - loss: 0.0732 - accuracy: 0.9726
# Epoch 00049: accuracy did not improve from 1.00000
# 56/75 [=====================>........] - ETA: 5:29 - loss: 0.0748 - accuracy: 0.9718
# Epoch 00049: accuracy did not improve from 1.00000
# 57/75 [=====================>........] - ETA: 5:12 - loss: 0.0746 - accuracy: 0.9720
# Epoch 00049: accuracy did not improve from 1.00000
# 58/75 [======================>.......] - ETA: 4:54 - loss: 0.0744 - accuracy: 0.9721
# Epoch 00049: accuracy did not improve from 1.00000
# 59/75 [======================>.......] - ETA: 4:37 - loss: 0.0737 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 60/75 [=======================>......] - ETA: 4:20 - loss: 0.0737 - accuracy: 0.9724
# Epoch 00049: accuracy did not improve from 1.00000
# 61/75 [=======================>......] - ETA: 4:02 - loss: 0.0739 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 62/75 [=======================>......] - ETA: 3:45 - loss: 0.0734 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 63/75 [========================>.....] - ETA: 3:28 - loss: 0.0732 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 64/75 [========================>.....] - ETA: 3:10 - loss: 0.0734 - accuracy: 0.9722
# Epoch 00049: accuracy did not improve from 1.00000
# 65/75 [=========================>....] - ETA: 2:53 - loss: 0.0730 - accuracy: 0.9722
# Epoch 00049: accuracy did not improve from 1.00000
# 66/75 [=========================>....] - ETA: 2:36 - loss: 0.0733 - accuracy: 0.9722
# Epoch 00049: accuracy did not improve from 1.00000
# 67/75 [=========================>....] - ETA: 2:18 - loss: 0.0730 - accuracy: 0.9724
# Epoch 00049: accuracy did not improve from 1.00000
# 68/75 [==========================>...] - ETA: 2:01 - loss: 0.0731 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 69/75 [==========================>...] - ETA: 1:44 - loss: 0.0731 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 70/75 [===========================>..] - ETA: 1:26 - loss: 0.0723 - accuracy: 0.9729
# Epoch 00049: accuracy did not improve from 1.00000
# 71/75 [===========================>..] - ETA: 1:09 - loss: 0.0729 - accuracy: 0.9727
# Epoch 00049: accuracy did not improve from 1.00000
# 72/75 [===========================>..] - ETA: 52s - loss: 0.0733 - accuracy: 0.9725
# Epoch 00049: accuracy did not improve from 1.00000
# 73/75 [============================>.] - ETA: 34s - loss: 0.0729 - accuracy: 0.9727
# Epoch 00049: accuracy did not improve from 1.00000
# 74/75 [============================>.] - ETA: 17s - loss: 0.0725 - accuracy: 0.9729
# Epoch 00049: accuracy did not improve from 1.00000
# 75/75 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9728
# Epoch 00049: accuracy did not improve from 1.00000
# 75/75 [==============================] - 1609s 22s/step - loss: 0.0727 - accuracy: 0.9728 - val_loss: 0.1383 - val_accuracy: 0.9666
# Epoch 50/50
#  1/75 [..............................] - ETA: 22:42 - loss: 0.0580 - accuracy: 0.9688
# Epoch 00050: accuracy did not improve from 1.00000
#  2/75 [..............................] - ETA: 21:02 - loss: 0.0634 - accuracy: 0.9727
# Epoch 00050: accuracy did not improve from 1.00000
#  3/75 [>.............................] - ETA: 20:48 - loss: 0.0606 - accuracy: 0.9740
# Epoch 00050: accuracy did not improve from 1.00000
#  4/75 [>.............................] - ETA: 20:31 - loss: 0.0534 - accuracy: 0.9766
# Epoch 00050: accuracy did not improve from 1.00000
#  5/75 [=>............................] - ETA: 20:14 - loss: 0.0508 - accuracy: 0.9797
# Epoch 00050: accuracy did not improve from 1.00000
#  6/75 [=>............................] - ETA: 20:01 - loss: 0.0574 - accuracy: 0.9766
# Epoch 00050: accuracy did not improve from 1.00000
#  7/75 [=>............................] - ETA: 19:44 - loss: 0.0592 - accuracy: 0.9766
# Epoch 00050: accuracy did not improve from 1.00000
#  8/75 [==>...........................] - ETA: 19:23 - loss: 0.0677 - accuracy: 0.9736
# Epoch 00050: accuracy did not improve from 1.00000
#  9/75 [==>...........................] - ETA: 19:04 - loss: 0.0720 - accuracy: 0.9705
# Epoch 00050: accuracy did not improve from 1.00000
# 10/75 [===>..........................] - ETA: 18:47 - loss: 0.0711 - accuracy: 0.9703
# Epoch 00050: accuracy did not improve from 1.00000
# 11/75 [===>..........................] - ETA: 18:32 - loss: 0.0687 - accuracy: 0.9716
# Epoch 00050: accuracy did not improve from 1.00000
# 12/75 [===>..........................] - ETA: 18:16 - loss: 0.0674 - accuracy: 0.9727
# Epoch 00050: accuracy did not improve from 1.00000
# 13/75 [====>.........................] - ETA: 17:58 - loss: 0.0716 - accuracy: 0.9724
# Epoch 00050: accuracy did not improve from 1.00000
# 14/75 [====>.........................] - ETA: 17:42 - loss: 0.0722 - accuracy: 0.9727
# Epoch 00050: accuracy did not improve from 1.00000
# 15/75 [=====>........................] - ETA: 17:24 - loss: 0.0713 - accuracy: 0.9729
# Epoch 00050: accuracy did not improve from 1.00000
# 16/75 [=====>........................] - ETA: 17:07 - loss: 0.0691 - accuracy: 0.9741
# Epoch 00050: accuracy did not improve from 1.00000
# 17/75 [=====>........................] - ETA: 16:49 - loss: 0.0679 - accuracy: 0.9752
# Epoch 00050: accuracy did not improve from 1.00000
# 18/75 [======>.......................] - ETA: 16:32 - loss: 0.0671 - accuracy: 0.9748
# Epoch 00050: accuracy did not improve from 1.00000
# 19/75 [======>.......................] - ETA: 16:14 - loss: 0.0655 - accuracy: 0.9757
# Epoch 00050: accuracy did not improve from 1.00000
# 20/75 [=======>......................] - ETA: 15:57 - loss: 0.0653 - accuracy: 0.9762
# Epoch 00050: accuracy did not improve from 1.00000
# 21/75 [=======>......................] - ETA: 15:40 - loss: 0.0692 - accuracy: 0.9740
# Epoch 00050: accuracy did not improve from 1.00000
# 22/75 [=======>......................] - ETA: 15:24 - loss: 0.0705 - accuracy: 0.9734
# Epoch 00050: accuracy did not improve from 1.00000
# 23/75 [========>.....................] - ETA: 15:08 - loss: 0.0708 - accuracy: 0.9738
# Epoch 00050: accuracy did not improve from 1.00000
# 24/75 [========>.....................] - ETA: 14:50 - loss: 0.0699 - accuracy: 0.9736
# Epoch 00050: accuracy did not improve from 1.00000
# 25/75 [=========>....................] - ETA: 14:33 - loss: 0.0702 - accuracy: 0.9731
# Epoch 00050: accuracy did not improve from 1.00000
# 26/75 [=========>....................] - ETA: 14:16 - loss: 0.0703 - accuracy: 0.9730
# Epoch 00050: accuracy did not improve from 1.00000
# 27/75 [=========>....................] - ETA: 13:59 - loss: 0.0689 - accuracy: 0.9737
# Epoch 00050: accuracy did not improve from 1.00000
# 28/75 [==========>...................] - ETA: 13:41 - loss: 0.0692 - accuracy: 0.9735
# Epoch 00050: accuracy did not improve from 1.00000
# 29/75 [==========>...................] - ETA: 13:24 - loss: 0.0694 - accuracy: 0.9739
# Epoch 00050: accuracy did not improve from 1.00000
# 30/75 [===========>..................] - ETA: 13:06 - loss: 0.0686 - accuracy: 0.9742
# Epoch 00050: accuracy did not improve from 1.00000
# 31/75 [===========>..................] - ETA: 12:48 - loss: 0.0688 - accuracy: 0.9740
# Epoch 00050: accuracy did not improve from 1.00000
# 32/75 [===========>..................] - ETA: 12:30 - loss: 0.0684 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 33/75 [============>.................] - ETA: 12:13 - loss: 0.0677 - accuracy: 0.9747
# Epoch 00050: accuracy did not improve from 1.00000
# 34/75 [============>.................] - ETA: 11:56 - loss: 0.0677 - accuracy: 0.9747
# Epoch 00050: accuracy did not improve from 1.00000
# 35/75 [=============>................] - ETA: 11:39 - loss: 0.0680 - accuracy: 0.9746
# Epoch 00050: accuracy did not improve from 1.00000
# 36/75 [=============>................] - ETA: 11:21 - loss: 0.0677 - accuracy: 0.9748
# Epoch 00050: accuracy did not improve from 1.00000
# 37/75 [=============>................] - ETA: 11:04 - loss: 0.0670 - accuracy: 0.9749
# Epoch 00050: accuracy did not improve from 1.00000
# 38/75 [==============>...............] - ETA: 10:47 - loss: 0.0680 - accuracy: 0.9743
# Epoch 00050: accuracy did not improve from 1.00000
# 39/75 [==============>...............] - ETA: 10:30 - loss: 0.0681 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 40/75 [===============>..............] - ETA: 10:12 - loss: 0.0673 - accuracy: 0.9748
# Epoch 00050: accuracy did not improve from 1.00000
# 41/75 [===============>..............] - ETA: 9:55 - loss: 0.0668 - accuracy: 0.9748
# Epoch 00050: accuracy did not improve from 1.00000
# 42/75 [===============>..............] - ETA: 9:37 - loss: 0.0675 - accuracy: 0.9743
# Epoch 00050: accuracy did not improve from 1.00000
# 43/75 [================>.............] - ETA: 9:20 - loss: 0.0679 - accuracy: 0.9742
# Epoch 00050: accuracy did not improve from 1.00000
# 44/75 [================>.............] - ETA: 9:02 - loss: 0.0683 - accuracy: 0.9741
# Epoch 00050: accuracy did not improve from 1.00000
# 45/75 [=================>............] - ETA: 8:45 - loss: 0.0678 - accuracy: 0.9741
# Epoch 00050: accuracy did not improve from 1.00000
# 46/75 [=================>............] - ETA: 8:28 - loss: 0.0676 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 47/75 [=================>............] - ETA: 8:10 - loss: 0.0672 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 48/75 [==================>...........] - ETA: 7:53 - loss: 0.0673 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 49/75 [==================>...........] - ETA: 7:35 - loss: 0.0669 - accuracy: 0.9746
# Epoch 00050: accuracy did not improve from 1.00000
# 50/75 [===================>..........] - ETA: 7:18 - loss: 0.0665 - accuracy: 0.9748
# Epoch 00050: accuracy did not improve from 1.00000
# 51/75 [===================>..........] - ETA: 7:00 - loss: 0.0660 - accuracy: 0.9750
# Epoch 00050: accuracy did not improve from 1.00000
# 52/75 [===================>..........] - ETA: 6:42 - loss: 0.0663 - accuracy: 0.9748
# Epoch 00050: accuracy did not improve from 1.00000
# 53/75 [====================>.........] - ETA: 6:25 - loss: 0.0658 - accuracy: 0.9751
# Epoch 00050: accuracy did not improve from 1.00000
# 54/75 [====================>.........] - ETA: 6:08 - loss: 0.0660 - accuracy: 0.9751
# Epoch 00050: accuracy did not improve from 1.00000
# 55/75 [=====================>........] - ETA: 5:50 - loss: 0.0666 - accuracy: 0.9750
# Epoch 00050: accuracy did not improve from 1.00000
# 56/75 [=====================>........] - ETA: 5:33 - loss: 0.0668 - accuracy: 0.9749
# Epoch 00050: accuracy did not improve from 1.00000
# 57/75 [=====================>........] - ETA: 5:15 - loss: 0.0662 - accuracy: 0.9751
# Epoch 00050: accuracy did not improve from 1.00000
# 58/75 [======================>.......] - ETA: 4:58 - loss: 0.0674 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 59/75 [======================>.......] - ETA: 4:40 - loss: 0.0681 - accuracy: 0.9742
# Epoch 00050: accuracy did not improve from 1.00000
# 60/75 [=======================>......] - ETA: 4:23 - loss: 0.0687 - accuracy: 0.9741
# Epoch 00050: accuracy did not improve from 1.00000
# 61/75 [=======================>......] - ETA: 4:05 - loss: 0.0682 - accuracy: 0.9744
# Epoch 00050: accuracy did not improve from 1.00000
# 62/75 [=======================>......] - ETA: 3:48 - loss: 0.0680 - accuracy: 0.9743
# Epoch 00050: accuracy did not improve from 1.00000
# 63/75 [========================>.....] - ETA: 3:30 - loss: 0.0683 - accuracy: 0.9742
# Epoch 00050: accuracy did not improve from 1.00000
# 64/75 [========================>.....] - ETA: 3:12 - loss: 0.0687 - accuracy: 0.9740
# Epoch 00050: accuracy did not improve from 1.00000
# 65/75 [=========================>....] - ETA: 2:55 - loss: 0.0697 - accuracy: 0.9736
# Epoch 00050: accuracy did not improve from 1.00000
# 66/75 [=========================>....] - ETA: 2:37 - loss: 0.0697 - accuracy: 0.9736
# Epoch 00050: accuracy did not improve from 1.00000
# 67/75 [=========================>....] - ETA: 2:20 - loss: 0.0698 - accuracy: 0.9735
# Epoch 00050: accuracy did not improve from 1.00000
# 68/75 [==========================>...] - ETA: 2:02 - loss: 0.0700 - accuracy: 0.9737
# Epoch 00050: accuracy did not improve from 1.00000
# 69/75 [==========================>...] - ETA: 1:45 - loss: 0.0701 - accuracy: 0.9736
# Epoch 00050: accuracy did not improve from 1.00000
# 70/75 [===========================>..] - ETA: 1:27 - loss: 0.0701 - accuracy: 0.9735
# Epoch 00050: accuracy did not improve from 1.00000
# 71/75 [===========================>..] - ETA: 1:10 - loss: 0.0703 - accuracy: 0.9735
# Epoch 00050: accuracy did not improve from 1.00000
# 72/75 [===========================>..] - ETA: 52s - loss: 0.0710 - accuracy: 0.9733
# Epoch 00050: accuracy did not improve from 1.00000
# 73/75 [============================>.] - ETA: 35s - loss: 0.0721 - accuracy: 0.9728
# Epoch 00050: accuracy did not improve from 1.00000
# 74/75 [============================>.] - ETA: 17s - loss: 0.0718 - accuracy: 0.9730
# Epoch 00050: accuracy did not improve from 1.00000
# 75/75 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9732
# Epoch 00050: accuracy did not improve from 1.00000
# 75/75 [==============================] - 1628s 22s/step - loss: 0.0713 - accuracy: 0.9732 - val_loss: 0.1393 - val_accuracy: 0.9653
